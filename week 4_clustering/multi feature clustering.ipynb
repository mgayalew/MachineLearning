# %%
import numpy as np

# %%
import pandas as pd

# %%
cd"..//..//..//..//..//..//Google Drive"
# Out:
# /Users/Mulemebet/Google Drive

# %%
wholesale= pd.read_csv("Wholesale customers data.csv")

# %%
wholesale
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# 5          2       3   9413   8259     5126     666              1795
# 6          2       3  12126   3199     6975     480              3140
# 7          2       3   7579   4956     9426    1669              3321
# 8          1       3   5963   3648     6192     425              1716
# 9          2       3   6006  11093    18881    1159              7425
# 10         2       3   3366   5403    12974    4400              5977
# 11         2       3  13146   1124     4523    1420               549
# ...

# %%
import graphlab

# %%
wholesale
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# 5          2       3   9413   8259     5126     666              1795
# 6          2       3  12126   3199     6975     480              3140
# 7          2       3   7579   4956     9426    1669              3321
# 8          1       3   5963   3648     6192     425              1716
# 9          2       3   6006  11093    18881    1159              7425
# 10         2       3   3366   5403    12974    4400              5977
# 11         2       3  13146   1124     4523    1420               549
# ...

# %%
sw_sale= graphlab.SFrame("Wholesale customers data.csv")
# Out:
# Finished parsing file /Users/Mulemebet/Google Drive/Wholesale customers data.csv
# Parsing completed. Parsed 100 lines in 0.053358 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,int,int,int,int,int,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /Users/Mulemebet/Google Drive/Wholesale customers data.csv
# Parsing completed. Parsed 440 lines in 0.016711 secs.

# %%
sw_sale
# Out:
# Columns:
# 	Channel	int
# 	Region	int
# 	Fresh	int
# 	Milk	int
# 	Grocery	int
# 	Frozen	int
# 	Detergents_Paper	int
# 	Delicassen	int
#
# Rows: 440
#
# Data:
# +---------+--------+-------+-------+---------+--------+------------------+------------+
# | Channel | Region | Fresh |  Milk | Grocery | Frozen | Detergents_Paper | Delicassen |
# +---------+--------+-------+-------+---------+--------+------------------+------------+
# |    2    |   3    | 12669 |  9656 |   7561  |  214   |       2674       |    1338    |
# |    2    |   3    |  7057 |  9810 |   9568  |  1762  |       3293       |    1776    |
# |    2    |   3    |  6353 |  8808 |   7684  |  2405  |       3516       |    7844    |
# |    1    |   3    | 13265 |  1196 |   4221  |  6404  |       507        |    1788    |
# |    2    |   3    | 22615 |  5410 |   7198  |  3915  |       1777       |    5185    |
# |    2    |   3    |  9413 |  8259 |   5126  |  666   |       1795       |    1451    |
# ...

# %%
Kmodel= graphlab.kmeans.create(sw_sale, num_clusters=4, features=['Fresh', 'Milk', 'Grocery','Frozen','Detergents_Paper', 'Delicassen'])
# Out:
# Batch size is larger than the input dataset. Switching to an exact Kmeans method.
# Choosing initial cluster centers with Kmeans++.
# +---------------+-----------+
# | Center number | Row index |
# +---------------+-----------+
# | 0             | 133       |
# | 1             | 284       |
# | 2             | 176       |
# | 3             | 188       |
# +---------------+-----------+
# Starting kmeans model training.
# Assigning points to initial cluster centers.
# +-----------+-------------------------------+
# | Iteration | Number of changed assignments |
# +-----------+-------------------------------+
# | 1         | 51                            |
# | 2         | 27                            |
# | 3         | 19                            |
# | 4         | 18                            |
# | 5         | 14                            |
# | 6         | 9                             |
# | 7         | 3                             |
# | 8         | 5                             |
# ...

# %%
Kmodel
# Out:
# Class                            : KmeansModel
#
# Schema
# ------
# Number of clusters               : 4
# Number of examples               : 440
# Number of feature columns        : 6
# Number of unpacked features      : 6
# Row label name                   : row_id
#
# Training Summary
# ----------------
# Training method                  : elkan
# Number of training iterations    : 10
# Batch size                       : 440
# Total training time (seconds)    : 0.0341
#
# Accessible fields
# -----------------
# cluster_id                      : An SFrame containing the cluster assignments.
# cluster_info                    : An SFrame containing the cluster centers.

# %%
Kmodel.name()
# Out:
# 'KmeansModel'

# %%
Kmodel.summary()
# Out:
# Class                            : KmeansModel
#
# Schema
# ------
# Number of clusters               : 4
# Number of examples               : 440
# Number of feature columns        : 6
# Number of unpacked features      : 6
# Row label name                   : row_id
#
# Training Summary
# ----------------
# Training method                  : elkan
# Number of training iterations    : 10
# Batch size                       : 440
# Total training time (seconds)    : 0.0341
#
# Accessible fields
# -----------------
# cluster_id                      : An SFrame containing the cluster assignments.
# cluster_info                    : An SFrame containing the cluster centers.

# %%
Kmodel.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:52103/index.html
# Opening Canvas in default web browser.
